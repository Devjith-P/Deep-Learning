# %%
import cv2
import matplotlib.pyplot as plt

# %%
face1 = cv2.imread('/home/devjith/Luminar/Deep Learning/files/faces/face1.jpeg')
face2 = cv2.imread('/home/devjith/Luminar/Deep Learning/files/faces/face2.jpeg')
face3 = cv2.imread('/home/devjith/Luminar/Deep Learning/files/faces/face3.jpeg')
face4 = cv2.imread('/home/devjith/Luminar/Deep Learning/files/faces/face4.jpeg')
face5 = cv2.imread('/home/devjith/Luminar/Deep Learning/files/faces/face5.jpeg')

# %%
rgb_face1 = cv2.cvtColor(face1,cv2.COLOR_BGR2RGB)
rgb_face2 = cv2.cvtColor(face2,cv2.COLOR_BGR2RGB)
rgb_face3 = cv2.cvtColor(face3,cv2.COLOR_BGR2RGB)
rgb_face4 = cv2.cvtColor(face4,cv2.COLOR_BGR2RGB)
rgb_face5 = cv2.cvtColor(face5,cv2.COLOR_BGR2RGB)

# %%
model = cv2.CascadeClassifier('/home/devjith/Luminar/Deep Learning/Face_Detection/haarcascade_frontalface_default.xml')
model
# Out:
# < cv2.CascadeClassifier 0x7ed3f8e9fa70>

# %%
faces = model.detectMultiScale(rgb_face3,minNeighbors=25)

# %%
faces
# Out:
# array([[572, 658,  75,  75],
#        [263, 689,  72,  72],
#        [ 38, 669,  88,  88],
#        [396, 675,  89,  89],
#        [745, 677,  85,  85]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(rgb_face3,(x,y),(x+w,y+h),color=(255,0,0),thickness=2)
plt.imshow(rgb_face3)
