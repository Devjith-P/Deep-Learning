# %%
import cv2

# %%
img = cv2.imread('/home/devjith/Luminar/Deep Learning/files/baby3.jpeg')

# %%
import matplotlib.pyplot as plt
rgb_img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
cv2.rectangle(rgb_img1,(50,10),(195,175),color=(255,0,0),thickness=2)
plt.imshow(rgb_img1)

# %%
img2 = cv2.imread('/home/devjith/Luminar/Deep Learning/files/baby.jpeg')

# %%
img2_rgb = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(img2_rgb)

# %%
cv2.rectangle(img2_rgb,(80,3),(160,95),color=(0,255,0),thickness=1)
plt.imshow(img2_rgb)

# %%
profile = cv2.imread('/home/devjith/Luminar/Deep Learning/files/Profile.jpg')
profile_rgb = cv2.cvtColor(profile,cv2.COLOR_BGR2RGB)
plt.imshow(profile_rgb)

# %%
cv2.circle(profile_rgb,(1550,1250),radius=500,color=(255,0,0),thickness=5)
plt.imshow(profile_rgb)

# %%
cbum = cv2.imread('/home/devjith/Luminar/Deep Learning/files/cbum.jpeg')

# %%
cbum_rgb = cv2.cvtColor(cbum,cv2.COLOR_BGR2RGB)
plt.imshow(cbum_rgb)

# %%
cv2.putText(cbum_rgb,text="CHAMPION",org=(50,90),fontFace=cv2.FONT_HERSHEY_COMPLEX,fontScale=1.2,color=(255,0,0),thickness=3)
plt.imshow(cbum_rgb)
