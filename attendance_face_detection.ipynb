# %%
import numpy as np
import pandas as pd
import os
import cv2
import face_recognition as fr
import matplotlib.pyplot as plt
import pyttsx3

# %%
path=r'D:\vs_code_DL\face recognition\images'

# %%
my_list=os.listdir(path)

# %%
imgs=[]
class_names=[]

# %%
for i in my_list:
    img_path=os.path.join(path,i)
    current_img=cv2.imread(img_path)
    imgs.append(current_img)
    class_names.append(i.split('.')[0])

# %% [markdown]
# for i in images:
#         img=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
#         face_in_frame=fr.face_locations(img)
#         # print(face_in_frame)
#         encoder=fr.face_encodings(img,face_in_frame)[0]
#         encode_list.append(encoder)
#         # print(encode_list)
#     return encode_list

# %%
def face_encodings(images):

    encode_list=[]


    for i in images:
        img=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
        face_in_frame=fr.face_locations(img)
        encoder=fr.face_encodings(img,face_in_frame)[0]
        encode_list.append(encoder)
    return encode_list

# %%
encode_known_faces=face_encodings(imgs)

# %% [markdown]
# video=cv2.VideoCapture(0)
# while True:
#     suc,img=video.read()
#     img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#     face_in_frame=fr.face_locations(img1)
#     # print(face_in_frame)
#     encoded_face=fr.face_encodings(img1,face_in_frame)
#     # print(encoded_face)
#
#
#
#     for face_loc,enc in zip(face_in_frame,encoded_face):
#         matches=fr.compare_faces(encode_known_face,enc)
#         # print(matches)
#         face_distance=fr.face_distance(encode_known_face,enc)
#         # print(face_distance)
#
#
#         match_index=np.argmin(face_distance)
#         if matches[match_index]==True:
#             name=class_names[match_index]
#             # print(name)
#
#             y1,x2,y2,x1=face_loc
#             cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),2)
#
#             cv2.putText(img,name,(x1,y1-15),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),1)
#         else:
#             y1,x2,y2,x1=face_loc
#             cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),2)
#             cv2.putText(img,'unknown',(x1,y1-15),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
#
#
#
#     cv2.imshow('video',img)
#     if cv2.waitKey(1) & 0XFF==ord('q'):
#         break
#
# video.release()
# cv2.destroyAllWindows()

# %%
from datetime import datetime

# %%
video = cv2.VideoCapture(0)

marked = []

while True:
    suc, img = video.read()
    img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    face_in_frame = fr.face_locations(img1)
    encoded = fr.face_encodings(img1, face_in_frame)

    today = datetime.now().strftime("%Y-%m-%d")
    file_name = f"attendance_{today}.csv"

    
    def attendance_mark_confirmation(name):
        txt_sp = pyttsx3.init()

        voices = txt_sp.getProperty('voices')
        txt_sp.setProperty('voice', voices[0].id) 

        txt_sp.setProperty('volume', 0.9)

        message = f"{name} attendance marked successfully"
       

        txt_sp.say(message)
        txt_sp.runAndWait()

    def mark_attendance(name):
        if name not in marked:
            time_now = datetime.now().strftime("%H:%M:%S")
            with open(file_name, "a") as f:
                f.write(f"{name},{time_now}\n")
            marked.append(name)
            attendance_mark_confirmation(name)

   
    for face_loc, enc in zip(face_in_frame, encoded):
        matches = fr.compare_faces(encode_known_faces, enc)
        face_distance = fr.face_distance(encode_known_faces, enc)
        match_index = np.argmin(face_distance)

        if matches[match_index] == True:
            name = class_names[match_index]
            mark_attendance(name)

    cv2.imshow('video', img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
